# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ignore  the warnings 
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
# !pip install vit_keras
# !pip install tensorflow_addons
# Out:
# Collecting vit_keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit_keras) (1.11.4)
# Collecting validators (from vit_keras)
#   Downloading validators-0.28.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->vit_keras) (1.25.2)
# Installing collected packages: validators, vit_keras
# Successfully installed validators-0.28.3 vit_keras-0.1.2
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
# data visualisation and manipulation
import numpy as np, pandas as pd, re, matplotlib.pyplot as plt, seaborn as sns, math, random

from matplotlib import style
from collections import Counter

#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score,precision_score, recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
import tensorflow as tf
from tensorflow.keras import layers
from keras import backend as K
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical
from vit_keras import vit
import tensorflow_addons as tfa

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization


import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
from tqdm import tqdm
import os
import glob
import tempfile
from PIL import Image

# %%
class CONFIG:
    HEIGHT = 224
    WIDTH = 224
    SEED = 42
    FOLDS = 5
    IMAGE_SIZES = [224, 224, 224, 224, 224] #same img size for each fold
    BATCH_SIZE = [16] * FOLDS
    EPOCHS = [15] * FOLDS
    WEIGHTS = [1/FOLDS] * FOLDS
    AUTO = tf.data.experimental.AUTOTUNE
    VERBOSE = 1

# %% [markdown]
# ## Augmentation

# %%
ROTATION = 180.0
SHEAR = 2.0
H_ZOOM = 8.0
W_ZOOM = 8.0
H_SHIFT = 8.0
W_SHIFT = 8.0

# %%
def get_matrix(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    rotation = math.pi * rotation / 180.
    shear = math.pi * shear / 180.
    def get_3x3_matrix(lst):
        return tf.reshape(tf.concat([lst], axis = 0), [3,3])
    #rotation
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1], dtype='float32')
    zero = tf.constant([0], dtype='float32')

    rotation_matrix = get_3x3_matrix([c1, s1, zero,
                                   -s1, c1, zero,
                                   zero, zero, one
                                ])
    # Shear matrix
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)

    shear_matrix = get_3x3_matrix([one, s2, zero,
                                zero, c2, zero,
                                zero, zero, one])

    #Zoom mat
    zoom_matrix = get_3x3_matrix([one/height_zoom, zero, zero,
                               zero, one/width_zoom, zero,
                               zero, zero, one])
    # Shift mat
    shift_matrix = get_3x3_matrix([one, zero, height_shift,
                               zero, one, width_shift,
                               zero, zero, one])
    return K.dot(K.dot(rotation_matrix, shear_matrix), K.dot(zoom_matrix, shift_matrix))

def transform(image, DIM=224):
    XDIM = DIM%2

    rot = ROTATION * tf.random.normal([1], dtype='float32')
    shr = SHEAR * tf.random.normal([1], dtype='float32')
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / H_ZOOM
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / W_ZOOM
    h_shift = H_SHIFT * tf.random.normal([1], dtype='float32')
    w_shift = W_SHIFT * tf.random.normal([1], dtype='float32')

    # get tranformation matrix
    m = get_matrix(rot, shr, h_zoom, w_zoom, h_shift, w_shift)
    #List Destination Pixel Indices
    x = tf.repeat(tf.range(DIM//2, -DIM//2, -1), DIM)
    y = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack([x, y, z])

    #Rotate Destination Pixels Onto Origin Pixels
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)

    #find origin Pixel Values
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d = tf.gather_nd(image, tf.transpose(idx3))

    return tf.reshape(d, [DIM, DIM, 3])

# %%
#NC
def read_labeled_tfrecord(example):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'label'                       : tf.io.FixedLenFeature([], tf.float32)
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    image = tf.io.decode_jpeg(example['image'], channels = 3)

    #Normalize the image in [0-1] range
    image = tf.image.convert_image_dtype(image, tf.float32)

    #GET THE LABEL
    label = example['label']

    return image, label

def prepare_image(img, augment=True, dim=224):

    if augment:
        img = transform(img, DIM=dim)
        img = tf.image.random_flip_left_right(img)
        #img = tf.image.random_hue(img, 0.01)
        img = tf.image.random_saturation(img, 0.7, 1.3)
        img = tf.image.random_contrast(img, 0.8, 1.2)
        img = tf.image.random_brightness(img, 0.1)

    #Resize the image if necessary
    img = tf.image.resize(img, [dim, dim])

    return img

def count_data_items(filenames):
    total_items = 0
    for filename in filenames:
        match = re.search(r'(test|train)(\d+)\.tfrec', filename)
        if match:
            total_items += 1
        else:
            print(f"Filename does not match the pattern: {filename}")
    return total_items

# %%
#NC
def get_dataset(files, augment = False, shuffle = False, repeat = False, labeled=True, return_image_names=True, batch_size=32, dim=224):

    ds = tf.data.TFRecordDataset(files, num_parallel_reads = tf.data.experimental.AUTOTUNE)
    ds = ds.cache()

    if repeat:
        ds = ds.repeat()

    if shuffle:
        ds = ds.shuffle(1024*8)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)

    if labeled:
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=CONFIG.AUTO)
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_names),
                    num_parallel_calls=CONFIG.AUTO)

    ds = ds.map(lambda img, label: (prepare_image(img, augment=augment, dim=dim), label), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.prefetch(CONFIG.AUTO)
    #Convert the images to a list of tensors
    images = []
    labels = []
    for features, label in ds:
        images.append(features.numpy())
        labels.append(label.numpy())

    return np.array(images), np.array(labels)

# %%
METRICS = [
    tf.keras.metrics.BinaryCrossentropy(name = 'Cross Entropy'),
    tf.keras.metrics.F1Score(name = 'f1_score'),
    tf.keras.metrics.TruePositives(name = 'TP'),
    tf.keras.metrics.FalsePositives(name = 'FP'),
    tf.keras.metrics.TrueNegatives(name = 'TN'),
    tf.keras.metrics.FalseNegatives(name = 'FN'),
    tf.keras.metrics.BinaryAccuracy(name = 'accuracy'),
    tf.keras.metrics.BinaryAccuracy(name='val_acc'),
    tf.keras.metrics.Precision(name = 'precision'),
    tf.keras.metrics.Recall(name = 'recall'),
    tf.keras.metrics.AUC(name = 'auc'),
    tf.keras.metrics.AUC(name = 'prc', curve = 'PR'), #precision recall curve
]

# %%
base_vit = vit.vit_b16(
    image_size = CONFIG.HEIGHT,
    activation = 'softmax',
    pretrained = True,
    include_top = False,
    pretrained_top = False,
    classes = 2
)
# Out:
# Downloading data from https://github.com/faustomorales/vit-keras/releases/download/dl/ViT-B_16_imagenet21k+imagenet2012.npz
# 347502902/347502902 [==============================] - 2s 0us/step

# %%
#NC
def build_model(dim=224):
    model = tf.keras.Sequential([
        base_vit,
        tf.keras.layers.Flatten(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(32, activation = tfa.activations.gelu),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(1, activation = 'sigmoid')
    ])
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.05)
    model.compile(optimizer = opt, loss=loss, metrics = METRICS)
    return model

# %%
#NC
def get_lr_callback(batch_size=8):
    lr_start   = 0.000005
    lr_max     = 0.00000125 * batch_size
    lr_min     = 0.000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8

    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max

        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)
    return lr_callback

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/skin_cancer'
# Out:
# /content/drive/MyDrive/Colab Notebooks/skin_cancer

# %%
# 32-16-8-4
DISPLAY_PLOT = True

# Define paths
tfrec_train_files = tf.io.gfile.glob('../../../dataset/task1/tf_records/train00.tfrec')
tfrec_test_files = tf.io.gfile.glob('../../../dataset/task1/tf_records/test00.tfrec')

#Load datasets
train_data, train_labels = get_dataset(tfrec_train_files, augment = True, shuffle = True, repeat = False, dim = 224)
test_data, test_labels = get_dataset(tfrec_test_files, augment = True, shuffle = False, repeat = False, dim = 224)

# Predictions array for test set
test_preds = np.zeros((count_data_items(tfrec_test_files), 1))

# Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits = CONFIG.FOLDS, shuffle = True, random_state = CONFIG.SEED)
oof_pred, oof_tar, oof_val, oof_folds = [], [], [],[]

for fold, (train_idx, val_idx) in enumerate(skf.split(train_data, train_labels)):

    print(f'\n___________________________FOLD {fold + 1}__________________________\n')

    # Create train and validation datasets
    train_subset_data, train_subset_labels = train_data[train_idx], train_labels[train_idx]
    val_subset_data, val_subset_labels = train_data[val_idx], train_labels[val_idx]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_subset_data, train_subset_labels))
    val_dataset = tf.data.Dataset.from_tensor_slices((val_subset_data, val_subset_labels))

    # Batch and shuffle datasets
    #.shuffle(len(train_subset_labels))
    train_dataset = train_dataset.batch(CONFIG.BATCH_SIZE[fold]).repeat()
    val_dataset = val_dataset.batch(CONFIG.BATCH_SIZE[fold])

    steps_per_epoch = len(train_subset_labels) // CONFIG.BATCH_SIZE[fold]
    validation_steps = len(val_subset_labels) // CONFIG.BATCH_SIZE[fold]

    # Class Weight

    # Build and compile model
    tf.keras.backend.clear_session()
    model = build_model(dim = 256)

    # Save best model checkpoint callback
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath = 'ViTb_16-fold-%i.h5'%fold,
                                                             monitor = 'val_loss', verbose = 0,
                                                             save_best_only = True, save_weights_only = True, mode = 'min',
                                                             save_freq = 'epoch')

    # Train Model
    print('Training ...')

    history = model.fit(train_dataset, epochs = CONFIG.EPOCHS[fold],
                        steps_per_epoch = steps_per_epoch, validation_data = val_dataset,
                        validation_steps = validation_steps, callbacks = [ checkpoint_callback,get_lr_callback(CONFIG.BATCH_SIZE[fold])],
                        verbose = CONFIG.VERBOSE)

    # Load best model weights
    print('Loading best model...')
    model.load_weights('ViTb_16-fold-%i.h5'%fold)

    # Predic OOF
    print('Predicting OOF with TTA...')
    val_preds = model.predict(val_dataset, verbose = 0)
    oof_pred.append(np.mean(val_preds, axis = 1))
    oof_tar.append(np.array([label.numpy() for _, label in val_dataset.unbatch()]))
    oof_folds.append(np.ones_like(oof_tar[-1], dtype = 'int8') * fold)

    # Predict on test set
    print('Predicting Test with TTA...')
    if fold == 0:
      test_preds = model.predict(test_data, verbose = 0)
    else:
      test_preds += model.predict(test_data, verbose = 0)

    test_preds += model.predict(test_data, verbose = 0 ) / CONFIG.FOLDS

    # cALCULATE AUC
    fold_auc = roc_auc_score(oof_tar[-1], oof_pred[-1])
    oof_val.append(np.max(history.history['val_auc']))
    print(f'#### FOLD {fold + 1} OOF AUC without TTA = {oof_val[-1]:.3f}, with TTA = {fold_auc:.3f}')

    # Plot training history
    if DISPLAY_PLOT:
        plt.figure(figsize = (15, 5))
        plt.plot(np.arange(CONFIG.EPOCHS[fold]), history.history['auc'], '-o', label = 'Train AUC', color = '#ff7f0e')
        plt.plot(np.arange(CONFIG.EPOCHS[fold]), history.history['val_auc'], '-o', label = 'Val AUC', color = '#1f77b4')
        x = np.argmax(history.history['val_auc'])
        y = np.max(history.history['val_auc'])
        xdist = plt.xlim()[1] - plt.xlim()[0]
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x, y, s = 200, color = '#1f77b4')
        plt.text(x - 0.03 * xdist, y - 0.13 * ydist, f'max auc \n {y:.2f}', size = 14)
        plt.ylabel('AUC', size = 14)
        plt.xlabel('Epoch', size = 14)
        plt.legend(loc = 2)

        plt2 = plt.gca().twinx()
        plt2.plot(np.arange(CONFIG.EPOCHS[fold]), history.history['loss'], '-o', label = 'Train Loss', color = '#2ca02c')
        plt.plot(np.arange(CONFIG.EPOCHS[fold]), history.history['val_loss'], '-o', label = 'Val Loss', color = '#d62728')
        x = np.argmin(history.history['val_loss'])
        y = np.min(history.history['val_loss'])
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x, y, s = 200, color = '#d62728')
        plt.text(x - 0.03 * xdist, y + 0.05 * ydist, 'min loss', size = 14)
        plt.ylabel('Loss', size = 14)
        plt.title(f'FOLD {fold + 1}')
        plt.legend(loc = 3)
        plt.show()
# Out:
# ___________________________FOLD 1__________________________
#
# Training ...
#
# Epoch 1: LearningRateScheduler setting learning rate to 5e-06.
# Epoch 1/15
# 107/107 [==============================] - 149s 864ms/step - loss: 0.8685 - Cross Entropy: 0.8676 - f1_score: 0.3174 - TP: 167.0000 - FP: 686.0000 - TN: 703.0000 - FN: 156.0000 - accuracy: 0.5082 - val_acc: 0.5082 - precision: 0.1958 - recall: 0.5170 - auc: 0.5217 - prc: 0.1986 - val_loss: 0.9552 - val_Cross Entropy: 0.9607 - val_f1_score: 0.3089 - val_TP: 59.0000 - val_FP: 228.0000 - val_TN: 112.0000 - val_FN: 17.0000 - val_accuracy: 0.4111 - val_val_acc: 0.4111 - val_precision: 0.2056 - val_recall: 0.7763 - val_auc: 0.5971 - val_prc: 0.2252 - lr: 5.0000e-06
#
# Epoch 2: LearningRateScheduler setting learning rate to 8.000000000000001e-06.
# Epoch 2/15
# 107/107 [==============================] - 97s 912ms/step - loss: 0.7432 - Cross Entropy: 0.7369 - f1_score: 0.3154 - TP: 227.0000 - FP: 641.0000 - TN: 744.0000 - FN: 92.0000 - accuracy: 0.5698 - val_acc: 0.5698 - precision: 0.2615 - recall: 0.7116 - auc: 0.6815 - prc: 0.3316 - val_loss: 0.8033 - val_Cross Entropy: 0.8005 - val_f1_score: 0.3089 - val_TP: 58.0000 - val_FP: 171.0000 - val_TN: 169.0000 - val_FN: 18.0000 - val_accuracy: 0.5457 - val_val_acc: 0.5457 - val_precision: 0.2533 - val_recall: 0.7632 - val_auc: 0.6654 - val_prc: 0.3061 - lr: 8.0000e-06
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.1000000000000001e-05.
# Epoch 3/15
# 107/107 [==============================] - 95s 890ms/step - loss: 0.6769 - Cross Entropy: 0.6664 - f1_score: 0.3162 - TP: 251.0000 - FP: 555.0000 - TN: 829.0000 - FN: 69.0000 - accuracy: 0.6338 - val_acc: 0.6338 - precision: 0.3114 - recall: 0.7844 - auc: 0.7766 - prc: 0.5023 - val_loss: 0.6370 - val_Cross Entropy: 0.6249 - val_f1_score: 0.3089 - val_TP: 41.0000 - val_FP: 111.0000 - val_TN: 229.0000 - val_FN: 35.0000 - val_accuracy: 0.6490 - val_val_acc: 0.6490 - val_precision: 0.2697 - val_recall: 0.5395 - val_auc: 0.6520 - val_prc: 0.3456 - lr: 1.1000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.4000000000000001e-05.
# Epoch 4/15
# 107/107 [==============================] - 81s 754ms/step - loss: 0.6282 - Cross Entropy: 0.6153 - f1_score: 0.3162 - TP: 271.0000 - FP: 501.0000 - TN: 883.0000 - FN: 49.0000 - accuracy: 0.6772 - val_acc: 0.6772 - precision: 0.3510 - recall: 0.8469 - auc: 0.8368 - prc: 0.6020 - val_loss: 0.6378 - val_Cross Entropy: 0.6247 - val_f1_score: 0.3089 - val_TP: 46.0000 - val_FP: 107.0000 - val_TN: 233.0000 - val_FN: 30.0000 - val_accuracy: 0.6707 - val_val_acc: 0.6707 - val_precision: 0.3007 - val_recall: 0.6053 - val_auc: 0.7028 - val_prc: 0.3811 - lr: 1.4000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.7000000000000003e-05.
# Epoch 5/15
# 107/107 [==============================] - 80s 749ms/step - loss: 0.5771 - Cross Entropy: 0.5603 - f1_score: 0.3187 - TP: 299.0000 - FP: 460.0000 - TN: 921.0000 - FN: 24.0000 - accuracy: 0.7160 - val_acc: 0.7160 - precision: 0.3939 - recall: 0.9257 - auc: 0.9015 - prc: 0.7165 - val_loss: 0.6947 - val_Cross Entropy: 0.6844 - val_f1_score: 0.3089 - val_TP: 59.0000 - val_FP: 135.0000 - val_TN: 205.0000 - val_FN: 17.0000 - val_accuracy: 0.6346 - val_val_acc: 0.6346 - val_precision: 0.3041 - val_recall: 0.7763 - val_auc: 0.7543 - val_prc: 0.4258 - lr: 1.7000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 2e-05.
# Epoch 6/15
# 107/107 [==============================] - 80s 747ms/step - loss: 0.5386 - Cross Entropy: 0.5180 - f1_score: 0.3170 - TP: 298.0000 - FP: 418.0000 - TN: 965.0000 - FN: 23.0000 - accuracy: 0.7412 - val_acc: 0.7412 - precision: 0.4162 - recall: 0.9283 - auc: 0.9239 - prc: 0.7946 - val_loss: 0.6651 - val_Cross Entropy: 0.6499 - val_f1_score: 0.3089 - val_TP: 51.0000 - val_FP: 105.0000 - val_TN: 235.0000 - val_FN: 25.0000 - val_accuracy: 0.6875 - val_val_acc: 0.6875 - val_precision: 0.3269 - val_recall: 0.6711 - val_auc: 0.7532 - val_prc: 0.4265 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.62e-05.
# Epoch 7/15
# 107/107 [==============================] - 93s 868ms/step - loss: 0.4813 - Cross Entropy: 0.4560 - f1_score: 0.3145 - TP: 307.0000 - FP: 336.0000 - TN: 1050.0000 - FN: 11.0000 - accuracy: 0.7964 - val_acc: 0.7964 - precision: 0.4774 - recall: 0.9654 - auc: 0.9662 - prc: 0.9022 - val_loss: 0.6266 - val_Cross Entropy: 0.6074 - val_f1_score: 0.3089 - val_TP: 55.0000 - val_FP: 99.0000 - val_TN: 241.0000 - val_FN: 21.0000 - val_accuracy: 0.7115 - val_val_acc: 0.7115 - val_precision: 0.3571 - val_recall: 0.7237 - val_auc: 0.7741 - val_prc: 0.4831 - lr: 1.6200e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.3160000000000004e-05.
# Epoch 8/15
# 107/107 [==============================] - 85s 793ms/step - loss: 0.4477 - Cross Entropy: 0.4183 - f1_score: 0.3162 - TP: 316.0000 - FP: 269.0000 - TN: 1115.0000 - FN: 4.0000 - accuracy: 0.8398 - val_acc: 0.8398 - precision: 0.5402 - recall: 0.9875 - auc: 0.9806 - prc: 0.9361 - val_loss: 0.6615 - val_Cross Entropy: 0.6424 - val_f1_score: 0.3089 - val_TP: 53.0000 - val_FP: 102.0000 - val_TN: 238.0000 - val_FN: 23.0000 - val_accuracy: 0.6995 - val_val_acc: 0.6995 - val_precision: 0.3419 - val_recall: 0.6974 - val_auc: 0.7833 - val_prc: 0.4616 - lr: 1.3160e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.0728000000000003e-05.
# Epoch 9/15
# 107/107 [==============================] - 85s 791ms/step - loss: 0.4214 - Cross Entropy: 0.3889 - f1_score: 0.3154 - TP: 315.0000 - FP: 265.0000 - TN: 1120.0000 - FN: 4.0000 - accuracy: 0.8421 - val_acc: 0.8421 - precision: 0.5431 - recall: 0.9875 - auc: 0.9861 - prc: 0.9572 - val_loss: 0.6916 - val_Cross Entropy: 0.6721 - val_f1_score: 0.3089 - val_TP: 53.0000 - val_FP: 104.0000 - val_TN: 236.0000 - val_FN: 23.0000 - val_accuracy: 0.6947 - val_val_acc: 0.6947 - val_precision: 0.3376 - val_recall: 0.6974 - val_auc: 0.7880 - val_prc: 0.4621 - lr: 1.0728e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 8.782400000000003e-06.
# Epoch 10/15
# 107/107 [==============================] - 84s 789ms/step - loss: 0.3969 - Cross Entropy: 0.3605 - f1_score: 0.3162 - TP: 315.0000 - FP: 225.0000 - TN: 1159.0000 - FN: 5.0000 - accuracy: 0.8650 - val_acc: 0.8650 - precision: 0.5833 - recall: 0.9844 - auc: 0.9903 - prc: 0.9686 - val_loss: 0.7084 - val_Cross Entropy: 0.6895 - val_f1_score: 0.3089 - val_TP: 54.0000 - val_FP: 111.0000 - val_TN: 229.0000 - val_FN: 22.0000 - val_accuracy: 0.6803 - val_val_acc: 0.6803 - val_precision: 0.3273 - val_recall: 0.7105 - val_auc: 0.7957 - val_prc: 0.4898 - lr: 8.7824e-06
#
# Epoch 11: LearningRateScheduler setting learning rate to 7.225920000000002e-06.
# Epoch 11/15
# 107/107 [==============================] - 84s 790ms/step - loss: 0.3773 - Cross Entropy: 0.3385 - f1_score: 0.3145 - TP: 314.0000 - FP: 186.0000 - TN: 1200.0000 - FN: 4.0000 - accuracy: 0.8885 - val_acc: 0.8885 - precision: 0.6280 - recall: 0.9874 - auc: 0.9937 - prc: 0.9777 - val_loss: 0.6749 - val_Cross Entropy: 0.6540 - val_f1_score: 0.3089 - val_TP: 51.0000 - val_FP: 93.0000 - val_TN: 247.0000 - val_FN: 25.0000 - val_accuracy: 0.7163 - val_val_acc: 0.7163 - val_precision: 0.3542 - val_recall: 0.6711 - val_auc: 0.7936 - val_prc: 0.4813 - lr: 7.2259e-06
#
# Epoch 12: LearningRateScheduler setting learning rate to 5.980736000000002e-06.
# Epoch 12/15
# 107/107 [==============================] - 84s 790ms/step - loss: 0.3602 - Cross Entropy: 0.3192 - f1_score: 0.3179 - TP: 322.0000 - FP: 185.0000 - TN: 1197.0000 - FN: 0.0000e+00 - accuracy: 0.8914 - val_acc: 0.8914 - precision: 0.6351 - recall: 1.0000 - auc: 0.9970 - prc: 0.9884 - val_loss: 0.6652 - val_Cross Entropy: 0.6424 - val_f1_score: 0.3089 - val_TP: 49.0000 - val_FP: 91.0000 - val_TN: 249.0000 - val_FN: 27.0000 - val_accuracy: 0.7163 - val_val_acc: 0.7163 - val_precision: 0.3500 - val_recall: 0.6447 - val_auc: 0.7910 - val_prc: 0.4851 - lr: 5.9807e-06
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.984588800000001e-06.
# Epoch 13/15
# 107/107 [==============================] - 80s 749ms/step - loss: 0.3544 - Cross Entropy: 0.3119 - f1_score: 0.3179 - TP: 320.0000 - FP: 161.0000 - TN: 1221.0000 - FN: 2.0000 - accuracy: 0.9043 - val_acc: 0.9043 - precision: 0.6653 - recall: 0.9938 - auc: 0.9956 - prc: 0.9852 - val_loss: 0.6784 - val_Cross Entropy: 0.6562 - val_f1_score: 0.3089 - val_TP: 53.0000 - val_FP: 92.0000 - val_TN: 248.0000 - val_FN: 23.0000 - val_accuracy: 0.7236 - val_val_acc: 0.7236 - val_precision: 0.3655 - val_recall: 0.6974 - val_auc: 0.7933 - val_prc: 0.4871 - lr: 4.9846e-06
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.187671040000001e-06.
# Epoch 14/15
# 107/107 [==============================] - 84s 788ms/step - loss: 0.3359 - Cross Entropy: 0.2903 - f1_score: 0.3195 - TP: 322.0000 - FP: 139.0000 - TN: 1241.0000 - FN: 2.0000 - accuracy: 0.9173 - val_acc: 0.9173 - precision: 0.6985 - recall: 0.9938 - auc: 0.9973 - prc: 0.9897 - val_loss: 0.6633 - val_Cross Entropy: 0.6395 - val_f1_score: 0.3089 - val_TP: 52.0000 - val_FP: 92.0000 - val_TN: 248.0000 - val_FN: 24.0000 - val_accuracy: 0.7212 - val_val_acc: 0.7212 - val_precision: 0.3611 - val_recall: 0.6842 - val_auc: 0.8003 - val_prc: 0.4970 - lr: 4.1877e-06
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.5501368320000016e-06.
# Epoch 15/15
# 107/107 [==============================] - 84s 788ms/step - loss: 0.3347 - Cross Entropy: 0.2887 - f1_score: 0.3162 - TP: 319.0000 - FP: 142.0000 - TN: 1242.0000 - FN: 1.0000 - accuracy: 0.9161 - val_acc: 0.9161 - precision: 0.6920 - recall: 0.9969 - auc: 0.9983 - prc: 0.9937 - val_loss: 0.6765 - val_Cross Entropy: 0.6530 - val_f1_score: 0.3089 - val_TP: 51.0000 - val_FP: 88.0000 - val_TN: 252.0000 - val_FN: 25.0000 - val_accuracy: 0.7284 - val_val_acc: 0.7284 - val_precision: 0.3669 - val_recall: 0.6711 - val_auc: 0.8008 - val_prc: 0.5000 - lr: 3.5501e-06
# Loading best model...
# Predicting OOF with TTA...
# Predicting Test with TTA...
# #### FOLD 1 OOF AUC without TTA = 0.801, with TTA = 0.780
# ___________________________FOLD 2__________________________
#
# Training ...
#
# Epoch 1: LearningRateScheduler setting learning rate to 5e-06.
# Epoch 1/15
# 107/107 [==============================] - 129s 802ms/step - loss: 0.7775 - Cross Entropy: 0.7490 - f1_score: 0.3151 - TP: 270.0000 - FP: 710.0000 - TN: 1020.0000 - FN: 128.0000 - accuracy: 0.6062 - val_acc: 0.6062 - precision: 0.2755 - recall: 0.6784 - auc: 0.6819 - prc: 0.3418 - val_loss: 0.8009 - val_Cross Entropy: 0.8000 - val_f1_score: 0.3055 - val_TP: 48.0000 - val_FP: 181.0000 - val_TN: 160.0000 - val_FN: 27.0000 - val_accuracy: 0.5000 - val_val_acc: 0.5000 - val_precision: 0.2096 - val_recall: 0.6400 - val_auc: 0.6065 - val_prc: 0.2844 - lr: 5.0000e-06
#
# Epoch 2: LearningRateScheduler setting learning rate to 8.000000000000001e-06.
# Epoch 2/15
# 107/107 [==============================] - 101s 952ms/step - loss: 0.6886 - Cross Entropy: 0.6785 - f1_score: 0.3145 - TP: 253.0000 - FP: 550.0000 - TN: 836.0000 - FN: 65.0000 - accuracy: 0.6391 - val_acc: 0.6391 - precision: 0.3151 - recall: 0.7956 - auc: 0.7699 - prc: 0.4801 - val_loss: 0.7307 - val_Cross Entropy: 0.7235 - val_f1_score: 0.3055 - val_TP: 56.0000 - val_FP: 141.0000 - val_TN: 200.0000 - val_FN: 19.0000 - val_accuracy: 0.6154 - val_val_acc: 0.6154 - val_precision: 0.2843 - val_recall: 0.7467 - val_auc: 0.7248 - val_prc: 0.4236 - lr: 8.0000e-06
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.1000000000000001e-05.
# Epoch 3/15
# 107/107 [==============================] - 92s 860ms/step - loss: 0.5990 - Cross Entropy: 0.5826 - f1_score: 0.3154 - TP: 292.0000 - FP: 461.0000 - TN: 924.0000 - FN: 27.0000 - accuracy: 0.7136 - val_acc: 0.7136 - precision: 0.3878 - recall: 0.9154 - auc: 0.8832 - prc: 0.6844 - val_loss: 0.7279 - val_Cross Entropy: 0.7193 - val_f1_score: 0.3055 - val_TP: 59.0000 - val_FP: 160.0000 - val_TN: 181.0000 - val_FN: 16.0000 - val_accuracy: 0.5769 - val_val_acc: 0.5769 - val_precision: 0.2694 - val_recall: 0.7867 - val_auc: 0.7648 - val_prc: 0.5098 - lr: 1.1000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.4000000000000001e-05.
# Epoch 4/15
# 107/107 [==============================] - 81s 754ms/step - loss: 0.5453 - Cross Entropy: 0.5248 - f1_score: 0.3170 - TP: 303.0000 - FP: 399.0000 - TN: 984.0000 - FN: 18.0000 - accuracy: 0.7553 - val_acc: 0.7553 - precision: 0.4316 - recall: 0.9439 - auc: 0.9240 - prc: 0.7907 - val_loss: 0.7433 - val_Cross Entropy: 0.7332 - val_f1_score: 0.3055 - val_TP: 61.0000 - val_FP: 146.0000 - val_TN: 195.0000 - val_FN: 14.0000 - val_accuracy: 0.6154 - val_val_acc: 0.6154 - val_precision: 0.2947 - val_recall: 0.8133 - val_auc: 0.7962 - val_prc: 0.5628 - lr: 1.4000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.7000000000000003e-05.
# Epoch 5/15
# 107/107 [==============================] - 84s 789ms/step - loss: 0.5012 - Cross Entropy: 0.4768 - f1_score: 0.3170 - TP: 302.0000 - FP: 359.0000 - TN: 1024.0000 - FN: 19.0000 - accuracy: 0.7782 - val_acc: 0.7782 - precision: 0.4569 - recall: 0.9408 - auc: 0.9537 - prc: 0.8616 - val_loss: 0.8042 - val_Cross Entropy: 0.7944 - val_f1_score: 0.3055 - val_TP: 63.0000 - val_FP: 159.0000 - val_TN: 182.0000 - val_FN: 12.0000 - val_accuracy: 0.5889 - val_val_acc: 0.5889 - val_precision: 0.2838 - val_recall: 0.8400 - val_auc: 0.8079 - val_prc: 0.5873 - lr: 1.7000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 2e-05.
# Epoch 6/15
# 107/107 [==============================] - 84s 787ms/step - loss: 0.4521 - Cross Entropy: 0.4216 - f1_score: 0.3170 - TP: 312.0000 - FP: 278.0000 - TN: 1105.0000 - FN: 9.0000 - accuracy: 0.8316 - val_acc: 0.8316 - precision: 0.5288 - recall: 0.9720 - auc: 0.9725 - prc: 0.9039 - val_loss: 0.7324 - val_Cross Entropy: 0.7174 - val_f1_score: 0.3055 - val_TP: 60.0000 - val_FP: 122.0000 - val_TN: 219.0000 - val_FN: 15.0000 - val_accuracy: 0.6707 - val_val_acc: 0.6707 - val_precision: 0.3297 - val_recall: 0.8000 - val_auc: 0.8067 - val_prc: 0.5730 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.62e-05.
# Epoch 7/15
# 107/107 [==============================] - 84s 788ms/step - loss: 0.4013 - Cross Entropy: 0.3648 - f1_score: 0.3154 - TP: 315.0000 - FP: 226.0000 - TN: 1159.0000 - FN: 4.0000 - accuracy: 0.8650 - val_acc: 0.8650 - precision: 0.5823 - recall: 0.9875 - auc: 0.9879 - prc: 0.9576 - val_loss: 0.8752 - val_Cross Entropy: 0.8612 - val_f1_score: 0.3055 - val_TP: 64.0000 - val_FP: 139.0000 - val_TN: 202.0000 - val_FN: 11.0000 - val_accuracy: 0.6394 - val_val_acc: 0.6394 - val_precision: 0.3153 - val_recall: 0.8533 - val_auc: 0.8288 - val_prc: 0.5641 - lr: 1.6200e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.3160000000000004e-05.
# Epoch 8/15
# 107/107 [==============================] - 91s 851ms/step - loss: 0.3588 - Cross Entropy: 0.3163 - f1_score: 0.3170 - TP: 317.0000 - FP: 147.0000 - TN: 1236.0000 - FN: 4.0000 - accuracy: 0.9114 - val_acc: 0.9114 - precision: 0.6832 - recall: 0.9875 - auc: 0.9928 - prc: 0.9765 - val_loss: 0.6483 - val_Cross Entropy: 0.6234 - val_f1_score: 0.3055 - val_TP: 56.0000 - val_FP: 92.0000 - val_TN: 249.0000 - val_FN: 19.0000 - val_accuracy: 0.7332 - val_val_acc: 0.7332 - val_precision: 0.3784 - val_recall: 0.7467 - val_auc: 0.8242 - val_prc: 0.5990 - lr: 1.3160e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.0728000000000003e-05.
# Epoch 9/15
# 107/107 [==============================] - 85s 792ms/step - loss: 0.3338 - Cross Entropy: 0.2865 - f1_score: 0.3162 - TP: 317.0000 - FP: 126.0000 - TN: 1258.0000 - FN: 3.0000 - accuracy: 0.9243 - val_acc: 0.9243 - precision: 0.7156 - recall: 0.9906 - auc: 0.9958 - prc: 0.9846 - val_loss: 0.7070 - val_Cross Entropy: 0.6846 - val_f1_score: 0.3055 - val_TP: 58.0000 - val_FP: 93.0000 - val_TN: 248.0000 - val_FN: 17.0000 - val_accuracy: 0.7356 - val_val_acc: 0.7356 - val_precision: 0.3841 - val_recall: 0.7733 - val_auc: 0.8093 - val_prc: 0.5812 - lr: 1.0728e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 8.782400000000003e-06.
# Epoch 10/15
# 107/107 [==============================] - 85s 791ms/step - loss: 0.3157 - Cross Entropy: 0.2652 - f1_score: 0.3137 - TP: 313.0000 - FP: 107.0000 - TN: 1280.0000 - FN: 4.0000 - accuracy: 0.9349 - val_acc: 0.9349 - precision: 0.7452 - recall: 0.9874 - auc: 0.9970 - prc: 0.9897 - val_loss: 0.7469 - val_Cross Entropy: 0.7230 - val_f1_score: 0.3055 - val_TP: 59.0000 - val_FP: 95.0000 - val_TN: 246.0000 - val_FN: 16.0000 - val_accuracy: 0.7332 - val_val_acc: 0.7332 - val_precision: 0.3831 - val_recall: 0.7867 - val_auc: 0.8239 - val_prc: 0.5522 - lr: 8.7824e-06
#
# Epoch 11: LearningRateScheduler setting learning rate to 7.225920000000002e-06.
# Epoch 11/15
# 107/107 [==============================] - 84s 789ms/step - loss: 0.3085 - Cross Entropy: 0.2559 - f1_score: 0.3137 - TP: 315.0000 - FP: 90.0000 - TN: 1297.0000 - FN: 2.0000 - accuracy: 0.9460 - val_acc: 0.9460 - precision: 0.7778 - recall: 0.9937 - auc: 0.9976 - prc: 0.9903 - val_loss: 0.6624 - val_Cross Entropy: 0.6377 - val_f1_score: 0.3055 - val_TP: 54.0000 - val_FP: 79.0000 - val_TN: 262.0000 - val_FN: 21.0000 - val_accuracy: 0.7596 - val_val_acc: 0.7596 - val_precision: 0.4060 - val_recall: 0.7200 - val_auc: 0.8016 - val_prc: 0.5889 - lr: 7.2259e-06
#
# Epoch 12: LearningRateScheduler setting learning rate to 5.980736000000002e-06.
# Epoch 12/15
# 107/107 [==============================] - 100s 940ms/step - loss: 0.2898 - Cross Entropy: 0.2342 - f1_score: 0.3170 - TP: 319.0000 - FP: 70.0000 - TN: 1313.0000 - FN: 2.0000 - accuracy: 0.9577 - val_acc: 0.9577 - precision: 0.8201 - recall: 0.9938 - auc: 0.9985 - prc: 0.9943 - val_loss: 0.6087 - val_Cross Entropy: 0.5812 - val_f1_score: 0.3055 - val_TP: 53.0000 - val_FP: 69.0000 - val_TN: 272.0000 - val_FN: 22.0000 - val_accuracy: 0.7812 - val_val_acc: 0.7812 - val_precision: 0.4344 - val_recall: 0.7067 - val_auc: 0.8055 - val_prc: 0.5827 - lr: 5.9807e-06
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.984588800000001e-06.
# Epoch 13/15
# 107/107 [==============================] - 104s 971ms/step - loss: 0.2873 - Cross Entropy: 0.2306 - f1_score: 0.3179 - TP: 321.0000 - FP: 80.0000 - TN: 1302.0000 - FN: 1.0000 - accuracy: 0.9525 - val_acc: 0.9525 - precision: 0.8005 - recall: 0.9969 - auc: 0.9988 - prc: 0.9950 - val_loss: 0.5802 - val_Cross Entropy: 0.5517 - val_f1_score: 0.3055 - val_TP: 50.0000 - val_FP: 64.0000 - val_TN: 277.0000 - val_FN: 25.0000 - val_accuracy: 0.7861 - val_val_acc: 0.7861 - val_precision: 0.4386 - val_recall: 0.6667 - val_auc: 0.8022 - val_prc: 0.6010 - lr: 4.9846e-06
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.187671040000001e-06.
# Epoch 14/15
# 107/107 [==============================] - 85s 792ms/step - loss: 0.2789 - Cross Entropy: 0.2207 - f1_score: 0.3162 - TP: 320.0000 - FP: 61.0000 - TN: 1323.0000 - FN: 0.0000e+00 - accuracy: 0.9642 - val_acc: 0.9642 - precision: 0.8399 - recall: 1.0000 - auc: 0.9994 - prc: 0.9976 - val_loss: 0.5972 - val_Cross Entropy: 0.5672 - val_f1_score: 0.3055 - val_TP: 52.0000 - val_FP: 61.0000 - val_TN: 280.0000 - val_FN: 23.0000 - val_accuracy: 0.7981 - val_val_acc: 0.7981 - val_precision: 0.4602 - val_recall: 0.6933 - val_auc: 0.8084 - val_prc: 0.5931 - lr: 4.1877e-06
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.5501368320000016e-06.
# Epoch 15/15
# 107/107 [==============================] - 84s 788ms/step - loss: 0.2734 - Cross Entropy: 0.2136 - f1_score: 0.3145 - TP: 317.0000 - FP: 58.0000 - TN: 1328.0000 - FN: 1.0000 - accuracy: 0.9654 - val_acc: 0.9654 - precision: 0.8453 - recall: 0.9969 - auc: 0.9991 - prc: 0.9965 - val_loss: 0.5805 - val_Cross Entropy: 0.5498 - val_f1_score: 0.3055 - val_TP: 50.0000 - val_FP: 58.0000 - val_TN: 283.0000 - val_FN: 25.0000 - val_accuracy: 0.8005 - val_val_acc: 0.8005 - val_precision: 0.4630 - val_recall: 0.6667 - val_auc: 0.8025 - val_prc: 0.5908 - lr: 3.5501e-06
# Loading best model...
# Predicting OOF with TTA...
# Predicting Test with TTA...
# #### FOLD 2 OOF AUC without TTA = 0.829, with TTA = 0.808
# ___________________________FOLD 3__________________________
#
# Training ...
#
# Epoch 1: LearningRateScheduler setting learning rate to 5e-06.
# Epoch 1/15
# 107/107 [==============================] - 139s 876ms/step - loss: 0.6989 - Cross Entropy: 0.6592 - f1_score: 0.3145 - TP: 308.0000 - FP: 635.0000 - TN: 1096.0000 - FN: 89.0000 - accuracy: 0.6598 - val_acc: 0.6598 - precision: 0.3266 - recall: 0.7758 - auc: 0.7891 - prc: 0.5358 - val_loss: 0.5263 - val_Cross Entropy: 0.5041 - val_f1_score: 0.3158 - val_TP: 74.0000 - val_FP: 100.0000 - val_TN: 238.0000 - val_FN: 4.0000 - val_accuracy: 0.7500 - val_val_acc: 0.7500 - val_precision: 0.4253 - val_recall: 0.9487 - val_auc: 0.9429 - val_prc: 0.8569 - lr: 5.0000e-06
#
# Epoch 2: LearningRateScheduler setting learning rate to 8.000000000000001e-06.
# Epoch 2/15
# 107/107 [==============================] - 107s 1s/step - loss: 0.5461 - Cross Entropy: 0.5186 - f1_score: 0.3145 - TP: 286.0000 - FP: 377.0000 - TN: 1009.0000 - FN: 32.0000 - accuracy: 0.7600 - val_acc: 0.7600 - precision: 0.4314 - recall: 0.8994 - auc: 0.9172 - prc: 0.8084 - val_loss: 0.4414 - val_Cross Entropy: 0.4014 - val_f1_score: 0.3158 - val_TP: 71.0000 - val_FP: 66.0000 - val_TN: 272.0000 - val_FN: 7.0000 - val_accuracy: 0.8245 - val_val_acc: 0.8245 - val_precision: 0.5182 - val_recall: 0.9103 - val_auc: 0.9536 - val_prc: 0.8908 - lr: 8.0000e-06
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.1000000000000001e-05.
# Epoch 3/15
# 107/107 [==============================] - 113s 1s/step - loss: 0.4624 - Cross Entropy: 0.4241 - f1_score: 0.3154 - TP: 287.0000 - FP: 289.0000 - TN: 1096.0000 - FN: 32.0000 - accuracy: 0.8116 - val_acc: 0.8116 - precision: 0.4983 - recall: 0.8997 - auc: 0.9368 - prc: 0.8675 - val_loss: 0.3681 - val_Cross Entropy: 0.3122 - val_f1_score: 0.3158 - val_TP: 66.0000 - val_FP: 31.0000 - val_TN: 307.0000 - val_FN: 12.0000 - val_accuracy: 0.8966 - val_val_acc: 0.8966 - val_precision: 0.6804 - val_recall: 0.8462 - val_auc: 0.9486 - val_prc: 0.8902 - lr: 1.1000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.4000000000000001e-05.
# Epoch 4/15
# 107/107 [==============================] - 85s 793ms/step - loss: 0.3826 - Cross Entropy: 0.3319 - f1_score: 0.3154 - TP: 299.0000 - FP: 189.0000 - TN: 1196.0000 - FN: 20.0000 - accuracy: 0.8773 - val_acc: 0.8773 - precision: 0.6127 - recall: 0.9373 - auc: 0.9716 - prc: 0.9313 - val_loss: 0.4633 - val_Cross Entropy: 0.4027 - val_f1_score: 0.3158 - val_TP: 66.0000 - val_FP: 35.0000 - val_TN: 303.0000 - val_FN: 12.0000 - val_accuracy: 0.8870 - val_val_acc: 0.8870 - val_precision: 0.6535 - val_recall: 0.8462 - val_auc: 0.9301 - val_prc: 0.8319 - lr: 1.4000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.7000000000000003e-05.
# Epoch 5/15
# 107/107 [==============================] - 84s 790ms/step - loss: 0.3503 - Cross Entropy: 0.2934 - f1_score: 0.3170 - TP: 297.0000 - FP: 130.0000 - TN: 1253.0000 - FN: 24.0000 - accuracy: 0.9096 - val_acc: 0.9096 - precision: 0.6956 - recall: 0.9252 - auc: 0.9735 - prc: 0.9317 - val_loss: 0.4731 - val_Cross Entropy: 0.4085 - val_f1_score: 0.3158 - val_TP: 66.0000 - val_FP: 30.0000 - val_TN: 308.0000 - val_FN: 12.0000 - val_accuracy: 0.8990 - val_val_acc: 0.8990 - val_precision: 0.6875 - val_recall: 0.8462 - val_auc: 0.9241 - val_prc: 0.8110 - lr: 1.7000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 2e-05.
# Epoch 6/15
# 107/107 [==============================] - 110s 1s/step - loss: 0.3118 - Cross Entropy: 0.2492 - f1_score: 0.3179 - TP: 305.0000 - FP: 97.0000 - TN: 1285.0000 - FN: 17.0000 - accuracy: 0.9331 - val_acc: 0.9331 - precision: 0.7587 - recall: 0.9472 - auc: 0.9835 - prc: 0.9590 - val_loss: 0.3318 - val_Cross Entropy: 0.2761 - val_f1_score: 0.3158 - val_TP: 57.0000 - val_FP: 8.0000 - val_TN: 330.0000 - val_FN: 21.0000 - val_accuracy: 0.9303 - val_val_acc: 0.9303 - val_precision: 0.8769 - val_recall: 0.7308 - val_auc: 0.9081 - val_prc: 0.8325 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.62e-05.
# Epoch 7/15
# 107/107 [==============================] - 109s 1s/step - loss: 0.2879 - Cross Entropy: 0.2201 - f1_score: 0.3145 - TP: 309.0000 - FP: 78.0000 - TN: 1308.0000 - FN: 9.0000 - accuracy: 0.9489 - val_acc: 0.9489 - precision: 0.7984 - recall: 0.9717 - auc: 0.9934 - prc: 0.9779 - val_loss: 0.3208 - val_Cross Entropy: 0.2646 - val_f1_score: 0.3158 - val_TP: 52.0000 - val_FP: 5.0000 - val_TN: 333.0000 - val_FN: 26.0000 - val_accuracy: 0.9255 - val_val_acc: 0.9255 - val_precision: 0.9123 - val_recall: 0.6667 - val_auc: 0.8849 - val_prc: 0.8118 - lr: 1.6200e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.3160000000000004e-05.
# Epoch 8/15
# 107/107 [==============================] - 85s 794ms/step - loss: 0.2632 - Cross Entropy: 0.1911 - f1_score: 0.3137 - TP: 308.0000 - FP: 53.0000 - TN: 1334.0000 - FN: 9.0000 - accuracy: 0.9636 - val_acc: 0.9636 - precision: 0.8532 - recall: 0.9716 - auc: 0.9936 - prc: 0.9829 - val_loss: 0.3324 - val_Cross Entropy: 0.2661 - val_f1_score: 0.3158 - val_TP: 60.0000 - val_FP: 11.0000 - val_TN: 327.0000 - val_FN: 18.0000 - val_accuracy: 0.9303 - val_val_acc: 0.9303 - val_precision: 0.8451 - val_recall: 0.7692 - val_auc: 0.9086 - val_prc: 0.8287 - lr: 1.3160e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.0728000000000003e-05.
# Epoch 9/15
# 107/107 [==============================] - 81s 753ms/step - loss: 0.2574 - Cross Entropy: 0.1837 - f1_score: 0.3170 - TP: 315.0000 - FP: 46.0000 - TN: 1337.0000 - FN: 6.0000 - accuracy: 0.9695 - val_acc: 0.9695 - precision: 0.8726 - recall: 0.9813 - auc: 0.9956 - prc: 0.9871 - val_loss: 0.4768 - val_Cross Entropy: 0.4071 - val_f1_score: 0.3158 - val_TP: 63.0000 - val_FP: 24.0000 - val_TN: 314.0000 - val_FN: 15.0000 - val_accuracy: 0.9062 - val_val_acc: 0.9062 - val_precision: 0.7241 - val_recall: 0.8077 - val_auc: 0.9115 - val_prc: 0.8078 - lr: 1.0728e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 8.782400000000003e-06.
# Epoch 10/15
# 107/107 [==============================] - 80s 752ms/step - loss: 0.2439 - Cross Entropy: 0.1676 - f1_score: 0.3145 - TP: 314.0000 - FP: 37.0000 - TN: 1349.0000 - FN: 4.0000 - accuracy: 0.9759 - val_acc: 0.9759 - precision: 0.8946 - recall: 0.9874 - auc: 0.9962 - prc: 0.9925 - val_loss: 0.3902 - val_Cross Entropy: 0.3190 - val_f1_score: 0.3158 - val_TP: 64.0000 - val_FP: 17.0000 - val_TN: 321.0000 - val_FN: 14.0000 - val_accuracy: 0.9255 - val_val_acc: 0.9255 - val_precision: 0.7901 - val_recall: 0.8205 - val_auc: 0.9254 - val_prc: 0.8377 - lr: 8.7824e-06
#
# Epoch 11: LearningRateScheduler setting learning rate to 7.225920000000002e-06.
# Epoch 11/15
# 107/107 [==============================] - 80s 751ms/step - loss: 0.2348 - Cross Entropy: 0.1566 - f1_score: 0.3145 - TP: 315.0000 - FP: 34.0000 - TN: 1352.0000 - FN: 3.0000 - accuracy: 0.9783 - val_acc: 0.9783 - precision: 0.9026 - recall: 0.9906 - auc: 0.9988 - prc: 0.9961 - val_loss: 0.3301 - val_Cross Entropy: 0.2644 - val_f1_score: 0.3158 - val_TP: 61.0000 - val_FP: 12.0000 - val_TN: 326.0000 - val_FN: 17.0000 - val_accuracy: 0.9303 - val_val_acc: 0.9303 - val_precision: 0.8356 - val_recall: 0.7821 - val_auc: 0.9169 - val_prc: 0.8418 - lr: 7.2259e-06
#
# Epoch 12: LearningRateScheduler setting learning rate to 5.980736000000002e-06.
# Epoch 12/15
# 107/107 [==============================] - 80s 751ms/step - loss: 0.2315 - Cross Entropy: 0.1522 - f1_score: 0.3154 - TP: 316.0000 - FP: 31.0000 - TN: 1354.0000 - FN: 3.0000 - accuracy: 0.9800 - val_acc: 0.9800 - precision: 0.9107 - recall: 0.9906 - auc: 0.9988 - prc: 0.9960 - val_loss: 0.3790 - val_Cross Entropy: 0.3089 - val_f1_score: 0.3158 - val_TP: 64.0000 - val_FP: 13.0000 - val_TN: 325.0000 - val_FN: 14.0000 - val_accuracy: 0.9351 - val_val_acc: 0.9351 - val_precision: 0.8312 - val_recall: 0.8205 - val_auc: 0.9255 - val_prc: 0.8471 - lr: 5.9807e-06
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.984588800000001e-06.
# Epoch 13/15
# 107/107 [==============================] - 80s 752ms/step - loss: 0.2214 - Cross Entropy: 0.1400 - f1_score: 0.3187 - TP: 321.0000 - FP: 29.0000 - TN: 1352.0000 - FN: 2.0000 - accuracy: 0.9818 - val_acc: 0.9818 - precision: 0.9171 - recall: 0.9938 - auc: 0.9997 - prc: 0.9989 - val_loss: 0.3413 - val_Cross Entropy: 0.2739 - val_f1_score: 0.3158 - val_TP: 60.0000 - val_FP: 12.0000 - val_TN: 326.0000 - val_FN: 18.0000 - val_accuracy: 0.9279 - val_val_acc: 0.9279 - val_precision: 0.8333 - val_recall: 0.7692 - val_auc: 0.9232 - val_prc: 0.8524 - lr: 4.9846e-06
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.187671040000001e-06.
# Epoch 14/15
# 107/107 [==============================] - 84s 790ms/step - loss: 0.2255 - Cross Entropy: 0.1443 - f1_score: 0.3154 - TP: 316.0000 - FP: 30.0000 - TN: 1355.0000 - FN: 3.0000 - accuracy: 0.9806 - val_acc: 0.9806 - precision: 0.9133 - recall: 0.9906 - auc: 0.9995 - prc: 0.9980 - val_loss: 0.3346 - val_Cross Entropy: 0.2662 - val_f1_score: 0.3158 - val_TP: 62.0000 - val_FP: 12.0000 - val_TN: 326.0000 - val_FN: 16.0000 - val_accuracy: 0.9327 - val_val_acc: 0.9327 - val_precision: 0.8378 - val_recall: 0.7949 - val_auc: 0.9225 - val_prc: 0.8561 - lr: 4.1877e-06
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.5501368320000016e-06.
# Epoch 15/15
# 107/107 [==============================] - 85s 791ms/step - loss: 0.2231 - Cross Entropy: 0.1414 - f1_score: 0.3154 - TP: 318.0000 - FP: 30.0000 - TN: 1355.0000 - FN: 1.0000 - accuracy: 0.9818 - val_acc: 0.9818 - precision: 0.9138 - recall: 0.9969 - auc: 0.9992 - prc: 0.9979 - val_loss: 0.3341 - val_Cross Entropy: 0.2673 - val_f1_score: 0.3158 - val_TP: 60.0000 - val_FP: 12.0000 - val_TN: 326.0000 - val_FN: 18.0000 - val_accuracy: 0.9279 - val_val_acc: 0.9279 - val_precision: 0.8333 - val_recall: 0.7692 - val_auc: 0.9204 - val_prc: 0.8492 - lr: 3.5501e-06
# Loading best model...
# Predicting OOF with TTA...
# Predicting Test with TTA...
# #### FOLD 3 OOF AUC without TTA = 0.954, with TTA = 0.885
# ___________________________FOLD 4__________________________
#
# Training ...
#
# Epoch 1: LearningRateScheduler setting learning rate to 5e-06.
# Epoch 1/15
# 107/107 [==============================] - 149s 945ms/step - loss: 0.7465 - Cross Entropy: 0.6461 - f1_score: 0.3165 - TP: 300.0000 - FP: 619.0000 - TN: 1109.0000 - FN: 100.0000 - accuracy: 0.6621 - val_acc: 0.6621 - precision: 0.3264 - recall: 0.7500 - auc: 0.7701 - prc: 0.5579 - val_loss: 0.5255 - val_Cross Entropy: 0.5085 - val_f1_score: 0.3192 - val_TP: 74.0000 - val_FP: 96.0000 - val_TN: 241.0000 - val_FN: 5.0000 - val_accuracy: 0.7572 - val_val_acc: 0.7572 - val_precision: 0.4353 - val_recall: 0.9367 - val_auc: 0.9462 - val_prc: 0.8758 - lr: 5.0000e-06
#
# Epoch 2: LearningRateScheduler setting learning rate to 8.000000000000001e-06.
# Epoch 2/15
# 107/107 [==============================] - 116s 1s/step - loss: 0.5287 - Cross Entropy: 0.5038 - f1_score: 0.3129 - TP: 289.0000 - FP: 417.0000 - TN: 971.0000 - FN: 27.0000 - accuracy: 0.7394 - val_acc: 0.7394 - precision: 0.4093 - recall: 0.9146 - auc: 0.9335 - prc: 0.8798 - val_loss: 0.3438 - val_Cross Entropy: 0.3047 - val_f1_score: 0.3192 - val_TP: 74.0000 - val_FP: 25.0000 - val_TN: 312.0000 - val_FN: 5.0000 - val_accuracy: 0.9279 - val_val_acc: 0.9279 - val_precision: 0.7475 - val_recall: 0.9367 - val_auc: 0.9792 - val_prc: 0.9505 - lr: 8.0000e-06
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.1000000000000001e-05.
# Epoch 3/15
# 107/107 [==============================] - 131s 1s/step - loss: 0.4470 - Cross Entropy: 0.4128 - f1_score: 0.3154 - TP: 301.0000 - FP: 289.0000 - TN: 1096.0000 - FN: 18.0000 - accuracy: 0.8198 - val_acc: 0.8198 - precision: 0.5102 - recall: 0.9436 - auc: 0.9637 - prc: 0.9257 - val_loss: 0.2814 - val_Cross Entropy: 0.2269 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 13.0000 - val_TN: 324.0000 - val_FN: 3.0000 - val_accuracy: 0.9615 - val_val_acc: 0.9615 - val_precision: 0.8539 - val_recall: 0.9620 - val_auc: 0.9929 - val_prc: 0.9827 - lr: 1.1000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.4000000000000001e-05.
# Epoch 4/15
# 107/107 [==============================] - 81s 757ms/step - loss: 0.4037 - Cross Entropy: 0.3639 - f1_score: 0.3154 - TP: 309.0000 - FP: 240.0000 - TN: 1145.0000 - FN: 10.0000 - accuracy: 0.8533 - val_acc: 0.8533 - precision: 0.5628 - recall: 0.9687 - auc: 0.9816 - prc: 0.9531 - val_loss: 0.3389 - val_Cross Entropy: 0.2845 - val_f1_score: 0.3192 - val_TP: 77.0000 - val_FP: 33.0000 - val_TN: 304.0000 - val_FN: 2.0000 - val_accuracy: 0.9159 - val_val_acc: 0.9159 - val_precision: 0.7000 - val_recall: 0.9747 - val_auc: 0.9879 - val_prc: 0.9775 - lr: 1.4000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.7000000000000003e-05.
# Epoch 5/15
# 107/107 [==============================] - 122s 1s/step - loss: 0.3544 - Cross Entropy: 0.3077 - f1_score: 0.3170 - TP: 313.0000 - FP: 159.0000 - TN: 1224.0000 - FN: 8.0000 - accuracy: 0.9020 - val_acc: 0.9020 - precision: 0.6631 - recall: 0.9751 - auc: 0.9886 - prc: 0.9732 - val_loss: 0.2572 - val_Cross Entropy: 0.1940 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 7.0000 - val_TN: 330.0000 - val_FN: 3.0000 - val_accuracy: 0.9760 - val_val_acc: 0.9760 - val_precision: 0.9157 - val_recall: 0.9620 - val_auc: 0.9955 - val_prc: 0.9881 - lr: 1.7000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 2e-05.
# Epoch 6/15
# 107/107 [==============================] - 121s 1s/step - loss: 0.3453 - Cross Entropy: 0.2967 - f1_score: 0.3170 - TP: 313.0000 - FP: 165.0000 - TN: 1218.0000 - FN: 8.0000 - accuracy: 0.8985 - val_acc: 0.8985 - precision: 0.6548 - recall: 0.9751 - auc: 0.9911 - prc: 0.9748 - val_loss: 0.2234 - val_Cross Entropy: 0.1593 - val_f1_score: 0.3192 - val_TP: 69.0000 - val_FP: 1.0000 - val_TN: 336.0000 - val_FN: 10.0000 - val_accuracy: 0.9736 - val_val_acc: 0.9736 - val_precision: 0.9857 - val_recall: 0.8734 - val_auc: 0.9929 - val_prc: 0.9812 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.62e-05.
# Epoch 7/15
# 107/107 [==============================] - 81s 754ms/step - loss: 0.3314 - Cross Entropy: 0.2810 - f1_score: 0.3137 - TP: 308.0000 - FP: 118.0000 - TN: 1269.0000 - FN: 9.0000 - accuracy: 0.9255 - val_acc: 0.9255 - precision: 0.7230 - recall: 0.9716 - auc: 0.9910 - prc: 0.9772 - val_loss: 0.2450 - val_Cross Entropy: 0.1816 - val_f1_score: 0.3192 - val_TP: 78.0000 - val_FP: 5.0000 - val_TN: 332.0000 - val_FN: 1.0000 - val_accuracy: 0.9856 - val_val_acc: 0.9856 - val_precision: 0.9398 - val_recall: 0.9873 - val_auc: 0.9991 - val_prc: 0.9965 - lr: 1.6200e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.3160000000000004e-05.
# Epoch 8/15
# 107/107 [==============================] - 126s 1s/step - loss: 0.3080 - Cross Entropy: 0.2534 - f1_score: 0.3154 - TP: 315.0000 - FP: 99.0000 - TN: 1286.0000 - FN: 4.0000 - accuracy: 0.9396 - val_acc: 0.9396 - precision: 0.7609 - recall: 0.9875 - auc: 0.9948 - prc: 0.9888 - val_loss: 0.2196 - val_Cross Entropy: 0.1542 - val_f1_score: 0.3192 - val_TP: 72.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 7.0000 - val_accuracy: 0.9784 - val_val_acc: 0.9784 - val_precision: 0.9730 - val_recall: 0.9114 - val_auc: 0.9946 - val_prc: 0.9844 - lr: 1.3160e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.0728000000000003e-05.
# Epoch 9/15
# 107/107 [==============================] - 85s 795ms/step - loss: 0.2989 - Cross Entropy: 0.2435 - f1_score: 0.3154 - TP: 316.0000 - FP: 79.0000 - TN: 1306.0000 - FN: 3.0000 - accuracy: 0.9519 - val_acc: 0.9519 - precision: 0.8000 - recall: 0.9906 - auc: 0.9981 - prc: 0.9932 - val_loss: 0.2483 - val_Cross Entropy: 0.1847 - val_f1_score: 0.3192 - val_TP: 77.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 2.0000 - val_accuracy: 0.9904 - val_val_acc: 0.9904 - val_precision: 0.9747 - val_recall: 0.9747 - val_auc: 0.9954 - val_prc: 0.9885 - lr: 1.0728e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 8.782400000000003e-06.
# Epoch 10/15
# 107/107 [==============================] - 81s 754ms/step - loss: 0.2929 - Cross Entropy: 0.2359 - f1_score: 0.3154 - TP: 319.0000 - FP: 90.0000 - TN: 1295.0000 - FN: 0.0000e+00 - accuracy: 0.9472 - val_acc: 0.9472 - precision: 0.7800 - recall: 1.0000 - auc: 0.9992 - prc: 0.9968 - val_loss: 0.2504 - val_Cross Entropy: 0.1877 - val_f1_score: 0.3192 - val_TP: 78.0000 - val_FP: 1.0000 - val_TN: 336.0000 - val_FN: 1.0000 - val_accuracy: 0.9952 - val_val_acc: 0.9952 - val_precision: 0.9873 - val_recall: 0.9873 - val_auc: 0.9980 - val_prc: 0.9942 - lr: 8.7824e-06
#
# Epoch 11: LearningRateScheduler setting learning rate to 7.225920000000002e-06.
# Epoch 11/15
# 107/107 [==============================] - 84s 790ms/step - loss: 0.2781 - Cross Entropy: 0.2194 - f1_score: 0.3145 - TP: 318.0000 - FP: 66.0000 - TN: 1320.0000 - FN: 0.0000e+00 - accuracy: 0.9613 - val_acc: 0.9613 - precision: 0.8281 - recall: 1.0000 - auc: 0.9998 - prc: 0.9991 - val_loss: 0.2504 - val_Cross Entropy: 0.1866 - val_f1_score: 0.3192 - val_TP: 77.0000 - val_FP: 3.0000 - val_TN: 334.0000 - val_FN: 2.0000 - val_accuracy: 0.9880 - val_val_acc: 0.9880 - val_precision: 0.9625 - val_recall: 0.9747 - val_auc: 0.9983 - val_prc: 0.9947 - lr: 7.2259e-06
#
# Epoch 12: LearningRateScheduler setting learning rate to 5.980736000000002e-06.
# Epoch 12/15
# 107/107 [==============================] - 80s 751ms/step - loss: 0.2816 - Cross Entropy: 0.2229 - f1_score: 0.3170 - TP: 320.0000 - FP: 65.0000 - TN: 1318.0000 - FN: 1.0000 - accuracy: 0.9613 - val_acc: 0.9613 - precision: 0.8312 - recall: 0.9969 - auc: 0.9993 - prc: 0.9978 - val_loss: 0.2429 - val_Cross Entropy: 0.1797 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 3.0000 - val_accuracy: 0.9880 - val_val_acc: 0.9880 - val_precision: 0.9744 - val_recall: 0.9620 - val_auc: 0.9967 - val_prc: 0.9890 - lr: 5.9807e-06
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.984588800000001e-06.
# Epoch 13/15
# 107/107 [==============================] - 80s 749ms/step - loss: 0.2719 - Cross Entropy: 0.2115 - f1_score: 0.3170 - TP: 321.0000 - FP: 68.0000 - TN: 1315.0000 - FN: 0.0000e+00 - accuracy: 0.9601 - val_acc: 0.9601 - precision: 0.8252 - recall: 1.0000 - auc: 0.9998 - prc: 0.9994 - val_loss: 0.2269 - val_Cross Entropy: 0.1614 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 3.0000 - val_accuracy: 0.9880 - val_val_acc: 0.9880 - val_precision: 0.9744 - val_recall: 0.9620 - val_auc: 0.9984 - val_prc: 0.9941 - lr: 4.9846e-06
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.187671040000001e-06.
# Epoch 14/15
# 107/107 [==============================] - 80s 752ms/step - loss: 0.2698 - Cross Entropy: 0.2093 - f1_score: 0.3170 - TP: 321.0000 - FP: 61.0000 - TN: 1322.0000 - FN: 0.0000e+00 - accuracy: 0.9642 - val_acc: 0.9642 - precision: 0.8403 - recall: 1.0000 - auc: 0.9999 - prc: 0.9997 - val_loss: 0.2234 - val_Cross Entropy: 0.1581 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 3.0000 - val_accuracy: 0.9880 - val_val_acc: 0.9880 - val_precision: 0.9744 - val_recall: 0.9620 - val_auc: 0.9992 - val_prc: 0.9967 - lr: 4.1877e-06
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.5501368320000016e-06.
# Epoch 15/15
# 107/107 [==============================] - 85s 791ms/step - loss: 0.2706 - Cross Entropy: 0.2100 - f1_score: 0.3145 - TP: 318.0000 - FP: 67.0000 - TN: 1319.0000 - FN: 0.0000e+00 - accuracy: 0.9607 - val_acc: 0.9607 - precision: 0.8260 - recall: 1.0000 - auc: 0.9998 - prc: 0.9993 - val_loss: 0.2253 - val_Cross Entropy: 0.1604 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 3.0000 - val_accuracy: 0.9880 - val_val_acc: 0.9880 - val_precision: 0.9744 - val_recall: 0.9620 - val_auc: 0.9987 - val_prc: 0.9949 - lr: 3.5501e-06
# Loading best model...
# Predicting OOF with TTA...
# Predicting Test with TTA...
# #### FOLD 4 OOF AUC without TTA = 0.999, with TTA = 0.995
# ___________________________FOLD 5__________________________
#
# Training ...
#
# Epoch 1: LearningRateScheduler setting learning rate to 5e-06.
# Epoch 1/15
# 107/107 [==============================] - 150s 945ms/step - loss: 0.6974 - Cross Entropy: 0.5780 - f1_score: 0.3178 - TP: 314.0000 - FP: 539.0000 - TN: 1187.0000 - FN: 88.0000 - accuracy: 0.7054 - val_acc: 0.7054 - precision: 0.3681 - recall: 0.7811 - auc: 0.8207 - prc: 0.7280 - val_loss: 0.4774 - val_Cross Entropy: 0.4453 - val_f1_score: 0.3192 - val_TP: 75.0000 - val_FP: 84.0000 - val_TN: 253.0000 - val_FN: 4.0000 - val_accuracy: 0.7885 - val_val_acc: 0.7885 - val_precision: 0.4717 - val_recall: 0.9494 - val_auc: 0.9602 - val_prc: 0.9544 - lr: 5.0000e-06
#
# Epoch 2: LearningRateScheduler setting learning rate to 8.000000000000001e-06.
# Epoch 2/15
# 107/107 [==============================] - 121s 1s/step - loss: 0.4265 - Cross Entropy: 0.3789 - f1_score: 0.3129 - TP: 298.0000 - FP: 268.0000 - TN: 1120.0000 - FN: 18.0000 - accuracy: 0.8322 - val_acc: 0.8322 - precision: 0.5265 - recall: 0.9430 - auc: 0.9639 - prc: 0.9350 - val_loss: 0.2903 - val_Cross Entropy: 0.2251 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 12.0000 - val_TN: 325.0000 - val_FN: 3.0000 - val_accuracy: 0.9639 - val_val_acc: 0.9639 - val_precision: 0.8636 - val_recall: 0.9620 - val_auc: 0.9729 - val_prc: 0.9696 - lr: 8.0000e-06
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.1000000000000001e-05.
# Epoch 3/15
# 107/107 [==============================] - 122s 1s/step - loss: 0.3571 - Cross Entropy: 0.2967 - f1_score: 0.3154 - TP: 303.0000 - FP: 182.0000 - TN: 1203.0000 - FN: 16.0000 - accuracy: 0.8838 - val_acc: 0.8838 - precision: 0.6247 - recall: 0.9498 - auc: 0.9754 - prc: 0.9569 - val_loss: 0.2295 - val_Cross Entropy: 0.1419 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 5.0000 - val_TN: 332.0000 - val_FN: 3.0000 - val_accuracy: 0.9808 - val_val_acc: 0.9808 - val_precision: 0.9383 - val_recall: 0.9620 - val_auc: 0.9812 - val_prc: 0.9741 - lr: 1.1000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.4000000000000001e-05.
# Epoch 4/15
# 107/107 [==============================] - 133s 1s/step - loss: 0.3207 - Cross Entropy: 0.2525 - f1_score: 0.3145 - TP: 303.0000 - FP: 134.0000 - TN: 1252.0000 - FN: 15.0000 - accuracy: 0.9126 - val_acc: 0.9126 - precision: 0.6934 - recall: 0.9528 - auc: 0.9906 - prc: 0.9732 - val_loss: 0.2024 - val_Cross Entropy: 0.1043 - val_f1_score: 0.3192 - val_TP: 73.0000 - val_FP: 0.0000e+00 - val_TN: 337.0000 - val_FN: 6.0000 - val_accuracy: 0.9856 - val_val_acc: 0.9856 - val_precision: 1.0000 - val_recall: 0.9241 - val_auc: 0.9870 - val_prc: 0.9785 - lr: 1.4000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.7000000000000003e-05.
# Epoch 5/15
# 107/107 [==============================] - 81s 753ms/step - loss: 0.3060 - Cross Entropy: 0.2344 - f1_score: 0.3179 - TP: 316.0000 - FP: 113.0000 - TN: 1269.0000 - FN: 6.0000 - accuracy: 0.9302 - val_acc: 0.9302 - precision: 0.7366 - recall: 0.9814 - auc: 0.9933 - prc: 0.9766 - val_loss: 0.2030 - val_Cross Entropy: 0.0993 - val_f1_score: 0.3192 - val_TP: 72.0000 - val_FP: 0.0000e+00 - val_TN: 337.0000 - val_FN: 7.0000 - val_accuracy: 0.9832 - val_val_acc: 0.9832 - val_precision: 1.0000 - val_recall: 0.9114 - val_auc: 0.9769 - val_prc: 0.9681 - lr: 1.7000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 2e-05.
# Epoch 6/15
# 107/107 [==============================] - 126s 1s/step - loss: 0.2808 - Cross Entropy: 0.2040 - f1_score: 0.3162 - TP: 315.0000 - FP: 93.0000 - TN: 1291.0000 - FN: 5.0000 - accuracy: 0.9425 - val_acc: 0.9425 - precision: 0.7721 - recall: 0.9844 - auc: 0.9968 - prc: 0.9893 - val_loss: 0.1856 - val_Cross Entropy: 0.0793 - val_f1_score: 0.3192 - val_TP: 77.0000 - val_FP: 1.0000 - val_TN: 336.0000 - val_FN: 2.0000 - val_accuracy: 0.9928 - val_val_acc: 0.9928 - val_precision: 0.9872 - val_recall: 0.9747 - val_auc: 0.9899 - val_prc: 0.9893 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.62e-05.
# Epoch 7/15
# 107/107 [==============================] - 81s 756ms/step - loss: 0.2833 - Cross Entropy: 0.2063 - f1_score: 0.3137 - TP: 312.0000 - FP: 80.0000 - TN: 1307.0000 - FN: 5.0000 - accuracy: 0.9501 - val_acc: 0.9501 - precision: 0.7959 - recall: 0.9842 - auc: 0.9925 - prc: 0.9825 - val_loss: 0.2150 - val_Cross Entropy: 0.1177 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 4.0000 - val_TN: 333.0000 - val_FN: 3.0000 - val_accuracy: 0.9832 - val_val_acc: 0.9832 - val_precision: 0.9500 - val_recall: 0.9620 - val_auc: 0.9924 - val_prc: 0.9874 - lr: 1.6200e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.3160000000000004e-05.
# Epoch 8/15
# 107/107 [==============================] - 80s 752ms/step - loss: 0.2684 - Cross Entropy: 0.1880 - f1_score: 0.3154 - TP: 314.0000 - FP: 65.0000 - TN: 1320.0000 - FN: 5.0000 - accuracy: 0.9589 - val_acc: 0.9589 - precision: 0.8285 - recall: 0.9843 - auc: 0.9939 - prc: 0.9851 - val_loss: 0.2105 - val_Cross Entropy: 0.1160 - val_f1_score: 0.3192 - val_TP: 73.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 6.0000 - val_accuracy: 0.9808 - val_val_acc: 0.9808 - val_precision: 0.9733 - val_recall: 0.9241 - val_auc: 0.9785 - val_prc: 0.9659 - lr: 1.3160e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.0728000000000003e-05.
# Epoch 9/15
# 107/107 [==============================] - 85s 791ms/step - loss: 0.2511 - Cross Entropy: 0.1679 - f1_score: 0.3162 - TP: 316.0000 - FP: 60.0000 - TN: 1324.0000 - FN: 4.0000 - accuracy: 0.9624 - val_acc: 0.9624 - precision: 0.8404 - recall: 0.9875 - auc: 0.9975 - prc: 0.9942 - val_loss: 0.2022 - val_Cross Entropy: 0.1022 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 3.0000 - val_accuracy: 0.9880 - val_val_acc: 0.9880 - val_precision: 0.9744 - val_recall: 0.9620 - val_auc: 0.9970 - val_prc: 0.9906 - lr: 1.0728e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 8.782400000000003e-06.
# Epoch 10/15
# 107/107 [==============================] - 81s 753ms/step - loss: 0.2443 - Cross Entropy: 0.1593 - f1_score: 0.3154 - TP: 316.0000 - FP: 64.0000 - TN: 1321.0000 - FN: 3.0000 - accuracy: 0.9607 - val_acc: 0.9607 - precision: 0.8316 - recall: 0.9906 - auc: 0.9986 - prc: 0.9961 - val_loss: 0.2208 - val_Cross Entropy: 0.1232 - val_f1_score: 0.3192 - val_TP: 77.0000 - val_FP: 7.0000 - val_TN: 330.0000 - val_FN: 2.0000 - val_accuracy: 0.9784 - val_val_acc: 0.9784 - val_precision: 0.9167 - val_recall: 0.9747 - val_auc: 0.9970 - val_prc: 0.9910 - lr: 8.7824e-06
#
# Epoch 11: LearningRateScheduler setting learning rate to 7.225920000000002e-06.
# Epoch 11/15
# 107/107 [==============================] - 80s 751ms/step - loss: 0.2373 - Cross Entropy: 0.1505 - f1_score: 0.3145 - TP: 318.0000 - FP: 57.0000 - TN: 1329.0000 - FN: 0.0000e+00 - accuracy: 0.9665 - val_acc: 0.9665 - precision: 0.8480 - recall: 1.0000 - auc: 0.9998 - prc: 0.9991 - val_loss: 0.2101 - val_Cross Entropy: 0.1120 - val_f1_score: 0.3192 - val_TP: 76.0000 - val_FP: 5.0000 - val_TN: 332.0000 - val_FN: 3.0000 - val_accuracy: 0.9808 - val_val_acc: 0.9808 - val_precision: 0.9383 - val_recall: 0.9620 - val_auc: 0.9961 - val_prc: 0.9892 - lr: 7.2259e-06
#
# Epoch 12: LearningRateScheduler setting learning rate to 5.980736000000002e-06.
# Epoch 12/15
# 107/107 [==============================] - 80s 753ms/step - loss: 0.2372 - Cross Entropy: 0.1505 - f1_score: 0.3170 - TP: 318.0000 - FP: 53.0000 - TN: 1330.0000 - FN: 3.0000 - accuracy: 0.9671 - val_acc: 0.9671 - precision: 0.8571 - recall: 0.9907 - auc: 0.9987 - prc: 0.9967 - val_loss: 0.1925 - val_Cross Entropy: 0.0926 - val_f1_score: 0.3192 - val_TP: 75.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 4.0000 - val_accuracy: 0.9856 - val_val_acc: 0.9856 - val_precision: 0.9740 - val_recall: 0.9494 - val_auc: 0.9940 - val_prc: 0.9864 - lr: 5.9807e-06
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.984588800000001e-06.
# Epoch 13/15
# 107/107 [==============================] - 85s 792ms/step - loss: 0.2323 - Cross Entropy: 0.1447 - f1_score: 0.3170 - TP: 321.0000 - FP: 44.0000 - TN: 1339.0000 - FN: 0.0000e+00 - accuracy: 0.9742 - val_acc: 0.9742 - precision: 0.8795 - recall: 1.0000 - auc: 0.9998 - prc: 0.9993 - val_loss: 0.1886 - val_Cross Entropy: 0.0901 - val_f1_score: 0.3192 - val_TP: 74.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 5.0000 - val_accuracy: 0.9832 - val_val_acc: 0.9832 - val_precision: 0.9737 - val_recall: 0.9367 - val_auc: 0.9921 - val_prc: 0.9823 - lr: 4.9846e-06
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.187671040000001e-06.
# Epoch 14/15
# 107/107 [==============================] - 80s 752ms/step - loss: 0.2322 - Cross Entropy: 0.1443 - f1_score: 0.3170 - TP: 320.0000 - FP: 48.0000 - TN: 1335.0000 - FN: 1.0000 - accuracy: 0.9712 - val_acc: 0.9712 - precision: 0.8696 - recall: 0.9969 - auc: 0.9997 - prc: 0.9988 - val_loss: 0.1913 - val_Cross Entropy: 0.0949 - val_f1_score: 0.3192 - val_TP: 74.0000 - val_FP: 2.0000 - val_TN: 335.0000 - val_FN: 5.0000 - val_accuracy: 0.9832 - val_val_acc: 0.9832 - val_precision: 0.9737 - val_recall: 0.9367 - val_auc: 0.9906 - val_prc: 0.9802 - lr: 4.1877e-06
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.5501368320000016e-06.
# Epoch 15/15
# 107/107 [==============================] - 85s 791ms/step - loss: 0.2350 - Cross Entropy: 0.1479 - f1_score: 0.3129 - TP: 316.0000 - FP: 47.0000 - TN: 1341.0000 - FN: 0.0000e+00 - accuracy: 0.9724 - val_acc: 0.9724 - precision: 0.8705 - recall: 1.0000 - auc: 0.9998 - prc: 0.9992 - val_loss: 0.2000 - val_Cross Entropy: 0.1088 - val_f1_score: 0.3192 - val_TP: 71.0000 - val_FP: 1.0000 - val_TN: 336.0000 - val_FN: 8.0000 - val_accuracy: 0.9784 - val_val_acc: 0.9784 - val_precision: 0.9861 - val_recall: 0.8987 - val_auc: 0.9774 - val_prc: 0.9690 - lr: 3.5501e-06
# Loading best model...
# Predicting OOF with TTA...
# Predicting Test with TTA...
# #### FOLD 5 OOF AUC without TTA = 0.997, with TTA = 0.990

# %%
def test_evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    # Convert predictions to binary (0, 1)
    predicted_labels = (predictions > 0.5).astype(int).flatten()

    # Classification Report
    report = classification_report(y_test, predicted_labels, target_names = ['Class 0', 'Class 1'], output_dict = True)

    # ROC AUC Score
    roc = roc_auc_score(y_test, predictions)
    print(f'ROC AUC Score: {roc}')

    # Confusion Matrix
    cm = confusion_matrix(y_test, predicted_labels)

    # Plot CM
    disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['Class 0', 'Class 1'])
    disp.plot()
    plt.show()

    # Metrics
    class_nevus_keratosis = report.get('Class 0', {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0})
    class_melanoma = report.get('Class 1', {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0})

    # Extract Metrics
    metrics_data = {
        'Metric': ['Precision', 'Recall', 'F1-Score', 'Support'],
        'Class 0': [class_nevus_keratosis['precision'], class_nevus_keratosis['recall'], class_nevus_keratosis['f1-score'], class_nevus_keratosis['support']],
        'Class 1': [class_melanoma['precision'], class_melanoma['recall'], class_melanoma['f1-score'], class_melanoma['support']],
        'Accuracy': [report['accuracy'], '', '', ''],
        'Macro-Avg': [report['macro avg']['precision'], report['macro avg']['recall'], report['macro avg']['f1-score'], ''],
        'Weighted-Avg': [report['weighted avg']['precision'], report['weighted avg']['recall'], report['weighted avg']['f1-score'], ''],
        'ROC-AUC-Score': [roc, '', '', '']
    }

    # Create DataFrame
    df_metrics = pd.DataFrame(metrics_data)

    # DataFrame for CM
    #df_conf_matrix = pd.DataFrame(cm, index = ['Actual 0', 'Actual 1'], columns = ['Predicted 0', 'Predicted 1'])

    #Display tables
    print("Classification Metrics:")
    print(df_metrics.to_string(index = False))
    #print("\n Confusion Matrix:")
    #print(df_conf_matrix.to_string(index = True))

# %%
# Example usage with your test data
tfrec_test = tf.io.gfile.glob(['../../../dataset/task1/tf_records/test00.tfrec'])
X_test, y_test = get_dataset(tfrec_test, augment=True, shuffle=True, repeat=False, dim = 224)

model = build_model(dim=224)
for fold in range(CONFIG.FOLDS):
    print(f"\n______________________FOLD {fold + 1}______________________\n")
    model.load_weights('ViTb_16-fold-%i.h5' % fold)
    test_evaluate(model, X_test, y_test)
# Out:
# ______________________FOLD 1______________________
#
# 19/19 [==============================] - 11s 446ms/step
# ROC AUC Score: 0.8103201146679407
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.928177   0.382353  0.711667  0.655265     0.821741       0.81032
#    Recall   0.695652   0.777778            0.736715     0.711667
#  F1-Score   0.795266   0.512676            0.653971     0.740161
#   Support 483.000000 117.000000
#
# ______________________FOLD 2______________________
#
# 19/19 [==============================] - 9s 452ms/step
# ROC AUC Score: 0.791934313673444
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.895592   0.426036  0.763333  0.660814     0.804028      0.791934
#    Recall   0.799172   0.615385            0.707278     0.763333
#  F1-Score   0.844639   0.503497            0.674068     0.778116
#   Support 483.000000 117.000000
#
# ______________________FOLD 3______________________
#
# 19/19 [==============================] - 9s 452ms/step
# ROC AUC Score: 0.7513581426624905
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.865385   0.587500  0.828333  0.726442     0.811197      0.751358
#    Recall   0.931677   0.401709            0.666693     0.828333
#  F1-Score   0.897308   0.477157            0.687233     0.815379
#   Support 483.000000 117.000000
#
# ______________________FOLD 4______________________
#
# 19/19 [==============================] - 9s 445ms/step
# ROC AUC Score: 0.7661517226734618
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.873047   0.590909  0.831667  0.731978      0.81803      0.766152
#    Recall   0.925466   0.444444            0.684955     0.831667
#  F1-Score   0.898492   0.507317            0.702905     0.822213
#   Support 483.000000 117.000000

# %%
# Example usage with your test data
tfrec_test = tf.io.gfile.glob(['../../../dataset/task1/tf_records/test00.tfrec'])
X_test, y_test = get_dataset(tfrec_test, augment=True, shuffle=True, repeat=False, dim = 224)

model = build_model(dim=224)
for fold in range(CONFIG.FOLDS):
    print(f"\n______________________FOLD {fold + 1}______________________\n")
    model.load_weights('ViTb_16-fold-%i.h5' % fold)
    test_evaluate(model, X_test, y_test)
# Out:
# ______________________FOLD 1______________________
#
# 19/19 [==============================] - 513s 27s/step
# ROC AUC Score: 0.7588964980269328
# Classification Metrics:
#    Metric    Class 0    Class 1 Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.898123   0.348018     0.69   0.62307     0.790853      0.758896
#    Recall   0.693582   0.675214           0.684398         0.69
#  F1-Score   0.782710   0.459302           0.621006     0.719646
#   Support 483.000000 117.000000
#
# ______________________FOLD 2______________________
#
# 19/19 [==============================] - 507s 27s/step
# ROC AUC Score: 0.780697563306259
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.903002   0.449102  0.776667  0.676052     0.814492      0.780698
#    Recall   0.809524   0.641026            0.725275     0.776667
#  F1-Score   0.853712   0.528169             0.69094     0.790231
#   Support 483.000000 117.000000
#
# ______________________FOLD 3______________________
#
# 19/19 [==============================] - 507s 27s/step
# ROC AUC Score: 0.7286015112102069
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.863894   0.633803  0.836667  0.748848     0.819026      0.728602
#    Recall   0.946170   0.384615            0.665393     0.836667
#  F1-Score   0.903162   0.478723            0.690943     0.820397
#   Support 483.000000 117.000000
#
# ______________________FOLD 4______________________
#
# 19/19 [==============================] - 507s 27s/step
# ROC AUC Score: 0.7572154093893224
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.873321   0.645570  0.843333  0.759445     0.828909      0.757215
#    Recall   0.942029   0.435897            0.688963     0.843333
#  F1-Score   0.906375   0.520408            0.713391     0.831111
#   Support 483.000000 117.000000
#
# ______________________FOLD 5______________________
#
# 19/19 [==============================] - 497s 26s/step
# ROC AUC Score: 0.7273805099892057
# Classification Metrics:
#    Metric    Class 0    Class 1  Accuracy Macro-Avg Weighted-Avg ROC-AUC-Score
# Precision   0.875486   0.616279  0.838333  0.745883     0.824941      0.727381
#    Recall   0.931677   0.452991            0.692334     0.838333
#  F1-Score   0.902708   0.522167            0.712438     0.828503
#   Support 483.000000 117.000000
